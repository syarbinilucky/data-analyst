# %% [markdown]
# <a href="https://colab.research.google.com/github/syarbinilucky/data-analyst/blob/main/scraping_data_wikipedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
#url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'
url = 'https://en.wikinews.org/wiki/2010_UK_general_election_results'

page = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c2c8e5dbd368> in <cell line: 0>()
#       2 url = 'https://en.wikinews.org/wiki/2010_UK_general_election_results'
#       3
# ----> 4 page = requests.get(url)
#
# NameError: name 'requests' is not defined

# %%
# cek output dari beautifulsoup

BeautifulSoup(page.text, 'html')
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>2010 UK general election results - Wikinews, the free news source</title>
# ...

# %%
soup = BeautifulSoup(page.text, 'html')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    2010 UK general election results - Wikinews, the free news source
#   </title>
#   <script>
# ...

# %%
soup.find_all('table')[2]
# Out:
# <table class="wikitable sortable" width="75%">
# <tbody><tr>
# <th width="50%">Constituency
# </th>
# <th class="unsortable">
# </th>
# <th>Result
# </th>
# <th>Votes
# </th>
# <th>Share
# </th>
# <th>Swing
# </th></tr>
# <tr>
# <td><a class="extiw" href="https://en.wikipedia.org/wiki/Aberavon_(UK_Parliament_constituency)" title="w:Aberavon (UK Parliament constituency)">Aberavon</a>
# </td>
# <td style="background:red" width="5px;">
# </td>
# <td><b>Labour hold</b>
# </td>
# <td>16,073
# </td>
# <td>51.9%
# </td>
# <td>5.3% (to LD)
# </td></tr>
# <tr>
# <td><a class="extiw" href="https://en.wikipedia.org/wiki/Aberconwy_(UK_Parliament_constituency)" title="w:Aberconwy (UK Parliament constituency)">Aberconwy</a>
# </td>
# <td style="background:blue" width="5px;">
# </td>
# <td><b>Conservative gain</b> from Lab
# </td>
# <td>10,734
# </td>
# <td>35.8%
# </td>
# <td>7.6%
# </td></tr>
# <tr>
# ...

# %%
tabel = soup.find_all('table')[2]

print(tabel.prettify())
# Out:
# <table class="wikitable sortable" width="75%">
#  <tbody>
#   <tr>
#    <th width="50%">
#     Constituency
#    </th>
#    <th class="unsortable">
#    </th>
#    <th>
#     Result
#    </th>
#    <th>
#     Votes
#    </th>
#    <th>
#     Share
#    </th>
#    <th>
#     Swing
#    </th>
#   </tr>
#   <tr>
#    <td>
#     <a class="extiw" href="https://en.wikipedia.org/wiki/Aberavon_(UK_Parliament_constituency)" title="w:Aberavon (UK Parliament constituency)">
#      Aberavon
#     </a>
#    </td>
#    <td style="background:red" width="5px;">
#    </td>
#    <td>
#     <b>
#      Labour hold
#     </b>
#    </td>
#    <td>
#     16,073
#    </td>
#    <td>
#     51.9%
#    </td>
#    <td>
#     5.3% (to LD)
#    </td>
#   </tr>
#   <tr>
#    <td>
#     <a class="extiw" href="https://en.wikipedia.org/wiki/Aberconwy_(UK_Parliament_constituency)" title="w:Aberconwy (UK Parliament constituency)">
#      Aberconwy
#     </a>
#    </td>
#    <td style="background:blue" width="5px;">
# ...

# %%
print(tabel_header)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-285bebe80fba> in <cell line: 1>()
# ----> 1 print(tabel_header)
#
# NameError: name 'tabel_header' is not defined

# %%
# seluruh konten halaman wikipedia

teks_biasa = soup.find_all('p')[2]
print(teks_biasa)
# Out:
# <p>The "Constituency" column shows the name of each constituency, linked to the relevant <i>Wikipedia</i> article. the "Result" column shows the winning party, and whether they held or gained the seat (and, if relevant, who they gained it from). The "Votes" column shows how many votes were received by the winning party, the "Share" column their share of the vote, and the "Swing" column the <span class="interwiki-link-foreign"><a class="extiw" href="https://en.wikipedia.org/wiki/Swing_(politics" title="w:Swing (politics">swing</a></span> in the direction of the gaining party.
# </p>

# %%
tabel_header = tabel.find_all('th')
print(tabel_header)
# Out:
# [<th width="50%">Constituency
# </th>, <th class="unsortable">
# </th>, <th>Result
# </th>, <th>Votes
# </th>, <th>Share
# </th>, <th>Swing
# </th>]

# %%
print(tabel_header)
# Out:
# [<th width="50%">Constituency
# </th>, <th class="unsortable">
# </th>, <th>Result
# </th>, <th>Votes
# </th>, <th>Share
# </th>, <th>Swing
# </th>]

# %%
tabel_header = tabel.find_all('th')
text_title_header = [title.text.strip() for title in tabel_header]

text_title_header
# Out:
# ['Constituency', '', 'Result', 'Votes', 'Share', 'Swing']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = text_title_header)
df
# Out:
# Empty DataFrame
# Columns: [Constituency, , Result, Votes, Share, Swing]
# Index: []

# %%
len(df)
# Out:
# 0

# %%
data_kolom = tabel.find_all('tr')
data_kolom
# Out:
# [<tr>
#  <th width="50%">Constituency
#  </th>
#  <th class="unsortable">
#  </th>
#  <th>Result
#  </th>
#  <th>Votes
#  </th>
#  <th>Share
#  </th>
#  <th>Swing
#  </th></tr>,
#  <tr>
#  <td><a class="extiw" href="https://en.wikipedia.org/wiki/Aberavon_(UK_Parliament_constituency)" title="w:Aberavon (UK Parliament constituency)">Aberavon</a>
#  </td>
#  <td style="background:red" width="5px;">
#  </td>
#  <td><b>Labour hold</b>
#  </td>
#  <td>16,073
#  </td>
#  <td>51.9%
#  </td>
#  <td>5.3% (to LD)
#  </td></tr>,
#  <tr>
#  <td><a class="extiw" href="https://en.wikipedia.org/wiki/Aberconwy_(UK_Parliament_constituency)" title="w:Aberconwy (UK Parliament constituency)">Aberconwy</a>
#  </td>
#  <td style="background:blue" width="5px;">
#  </td>
#  <td><b>Conservative gain</b> from Lab
#  </td>
#  <td>10,734
#  </td>
#  <td>35.8%
#  </td>
#  <td>7.6%
#  </td></tr>,
#  <tr>
# ...

# %%
# loop setiap data pada 'td'
for row in data_kolom[1:]:
    row_data = row.find_all('td')
    data_individu = [data.text.strip() for data in row_data]


    length = len(df)
    df.loc[length] = data_individu

# %%
df
# Out:
#                          Constituency     \
# 0                            Aberavon
# 1                           Aberconwy
# 2                      Aberdeen North
# 3                      Aberdeen South
# 4    Aberdeenshire West and Kincardie
# ..                                ... ..
# 645                            Yeovil
# 646                          Ynys Mon
# 647                      York Central
# 648                        York Outer
# 649                    Yorkshire East
#
#                                        Result   Votes  Share          Swing
# 0                                 Labour hold  16,073  51.9%   5.3% (to LD)
# 1                  Conservative gain from Lab  10,734  35.8%           7.6%
# 2                                 Labour hold  16,746  44.4%           1.0%
# 3                                 Labour hold  15,722  36.5%           2.5%
# 4                       Liberal Democrat hold  17,362  38.4%  4.9% (to CON)
# ...

# %%
df.to_csv('tabel_companies.csv', index=False)
